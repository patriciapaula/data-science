# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciapaula/data-science/blob/master/fake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow.keras as keras
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/wpp_2020.csv")
data
# Out:
#       shares                                               text  \
# 0         27  O ministro da Ciência, Tecnologia, Inovações e...
# 1         26  Pesquisa com mais de 6.000 médicos em 30 paíse...
# 2         25  É com muita alegria que comunico que mais um p...
# 3         25  Renda Brasil unificará vários programas sociai...
# 4         24  O Secretário-Geral da OTAN Jens Stoltenberg ta...
# ...      ...                                                ...
# 2893       1  A torcida do corona deve estar arrancando os c...
# 2894       1  “OS EUA E O CORONAVÍRUS :\r\n\r\nAcabei de ass...
# 2895       1  Estatísticas falsas conforme depoimentos colhi...
# 2896       1  Atenção => 🇧🇷💓💓💓 *MUITO IMPORTANTE! "Como é qu...
# 2897       1  [2:36 PM, 11/06/2020] Wellington: ```*ALERTA A...
#
#       misinformation                                             source  \
# 0                  0  https://www.gov.br/pt-br/noticias/educacao-e-p...
# ...

# %%
X = data[['text','misinformation']]
y = data['misinformation']

# %%
X
# Out:
#                                                    text  misinformation
# 0     O ministro da Ciência, Tecnologia, Inovações e...               0
# 1     Pesquisa com mais de 6.000 médicos em 30 paíse...               1
# 2     É com muita alegria que comunico que mais um p...               0
# 3     Renda Brasil unificará vários programas sociai...               0
# 4     O Secretário-Geral da OTAN Jens Stoltenberg ta...               0
# ...                                                 ...             ...
# 2893  A torcida do corona deve estar arrancando os c...               0
# 2894  “OS EUA E O CORONAVÍRUS :\r\n\r\nAcabei de ass...               0
# 2895  Estatísticas falsas conforme depoimentos colhi...               1
# 2896  Atenção => 🇧🇷💓💓💓 *MUITO IMPORTANTE! "Como é qu...               0
# 2897  [2:36 PM, 11/06/2020] Wellington: ```*ALERTA A...               1
#
# [2898 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
x_train
# Out:
# 2683    *🔴URGENTE CURA DEFINITIVA DO COVID-19!!*\r\n\r...
# 1293    SEX DATING FOR SÃO PAULO > http://sex-dating-c...
# 1033    Vi hoje uma postagem de uma pessoa perguntando...
# 177     *URGENTE: CHINA FECHA ACORDO COM A GLOBO*\r\n\...
# 426     Respondeu o que eu havia perguntado...tomou a ...
#                               ...
# 1638    *PROVÁVEL CENÁRIO POLÍTICO PARA 2022*\r\n🇧🇷🇧🇷🇧...
# 1095    https://www.factcheck.org/2020/02/no-link-betw...
# 1130    Eu tenho dito, tem armação politiqueira aí, te...
# 1294    Como se não bastasseo terror psicológico feito...
# 860     *CURTAM NOSSA PÁGINA*\r\nhttps://www.facebook....
# Name: text, Length: 1941, dtype: object

# %%
#usando regressão linear
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-23cbd05b7290> in <cell line: 3>()
#       1 #usando regressão linear
#       2 regr = linear_model.LinearRegression()
# ----> 3 regr.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
# ...
